# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### **1**
#
# 1. Defina dos listas de valores `x` e `y`, tal que los pares (x,y) cumplan una relación lineal del tipo $y = 2x + 1$. Defina la lista de valores de `x` con 100 puntos en el intervalo de valores que van desde -1 hasta 1.

# %%
x = np.linspace(-1, 1, 100)
y = 2 * x + 1

# %% [markdown]
# 2. Grafique la curva generada por los valores (x,y) en color verde, con un ancho `linewidth = 3` y que sea una línea a trazos `linestyle = '--'`. Agregue al gráfico el título 'Relación Lineal'.

# %%
plt.plot(x, y, linewidth = 3, linestyle = '--', color = "green")
plt.title("Relación Lineal")
plt.show()

# %% [markdown]
# ### **2**
#
# Graficar tres subplots, con las curvas (x1,y1),(x2,y2) y (x3,y3), en una única figura. Apilar los subplots en forma vertical y de manera que compartan el eje x.

# %%
x1 = np.linspace(0.0, 3.0 , 100)
x2 = np.linspace(0.0, 3.0, 100)
x3 = np.linspace(0.0, 3.0, 100)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)
y3 = 0.5 * x3 - 1

# %%
fig, ax = plt.subplots(3,1, sharex = True)

ax[0].plot(x1, y1)
ax[1].plot(x2, y2)
ax[2].plot(x3, y3)

# %% [markdown]
# ### **3**
# 1. ¿Por qué cree que se forman esas líneas horizontales en el gráfico?
# 2. ¿Qué conclusiones pueden sacar sobre la relación de precio y puntaje observando este gráfico?
# 3. Tome solo los vinos realizados en Argentina (recuerde usar una máscara) y realice nuevamente un scatter plot de precio vs puntaje para estos vinos.

# %%
reviews = pd.read_csv("Datasets\wine_reviews.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\javig\AppData\Local\Temp\ipykernel_123520\1942308967.py:1: SyntaxWarning: invalid escape sequence '\w'
#   reviews = pd.read_csv("Datasets\wine_reviews.csv")

# %%
arg_reviews = reviews[reviews['country'] == 'Argentina']
arg_reviews.head()
# Out:
#      Unnamed: 0    country                                        description  \
# 16           16  Argentina  Baked plum, molasses, balsamic vinegar and che...
# 17           17  Argentina  Raw black-cherry aromas are direct and simple ...
# 183         183  Argentina  With attractive melon and other tropical aroma...
# 224         224  Argentina  Blackberry and road-tar aromas are dark and st...
# 231         231  Argentina  Meaty and rubbery, but that's young Bonarda. T...
#
#              designation  points  price          province       region_1  \
# 16                 Felix      87   30.0             Other       Cafayate
# 17   Winemaker Selection      87   13.0  Mendoza Province        Mendoza
# 183                  NaN      88   12.0             Other          Salta
# 224                Lunta      90   22.0  Mendoza Province  Luján de Cuyo
# 231                  NaN      85   10.0  Mendoza Province        Mendoza
#
#     region_2        taster_name taster_twitter_handle  \
# 16       NaN  Michael Schachner           @wineschach
# 17       NaN  Michael Schachner           @wineschach
# 183      NaN  Michael Schachner           @wineschach
# 224      NaN  Michael Schachner           @wineschach
# 231      NaN  Michael Schachner           @wineschach
#
#                                                  title    variety  \
# 16          Felix Lavaque 2010 Felix Malbec (Cafayate)     Malbec
# 17   Gaucho Andino 2011 Winemaker Selection Malbec ...     Malbec
# 183                      Alamos 2007 Torrontés (Salta)  Torrontés
# 224           Mendel 2014 Lunta Malbec (Luján de Cuyo)     Malbec
# 231                  Andean Sky 2007 Bonarda (Mendoza)    Bonarda
#
#             winery
# 16   Felix Lavaque
# 17   Gaucho Andino
# 183         Alamos
# 224         Mendel
# 231     Andean Sky

# %%
arg_precios = arg_reviews['price']
print(arg_precios.head(), "\n")

arg_puntajes = arg_reviews['points']
print(arg_puntajes.head())
# Out:
# 16     30.0
# 17     13.0
# 183    12.0
# 224    22.0
# 231    10.0
# Name: price, dtype: float64
#
# 16     87
# 17     87
# 183    88
# 224    90
# 231    85
# Name: points, dtype: int64

# %%
plt.scatter(arg_precios, arg_puntajes)
plt.title("Precio vs Puntaje de Vinos Argentinos")
plt.xlabel("Precio")
plt.ylabel("Puntaje")
# Out:
# Text(0, 0.5, 'Puntaje')

# %% [markdown]
# ### **4**
#
# 1. Repitan el histograma anterior, pero esta vez cambiando el número de `bins`. Por ejemplo, probar con 5, 50, 500 y 5000. ¿Cuál les parece la opción más adecuada? ¿De qué dependará el número de bins adecuado a seleccionar?
#
# 2. Prueben qué sucede si no le pasan el argumento `bins` a la función. Busquen en la bibliografía de la librería que es lo que hace por default la función.

# %%
miu = 20
sigma = 4
valores = miu + sigma * np.random.randn(1000)

# %%
for bin in [5, 50, 500, 5000]:
    fig, ax = plt.subplots()
    plt.hist(valores, bins = bin)

# %%
n, bins, _ = plt.hist(valores)
print('n:', n, '\n', 'bins:', len(bins) - 1)
# Out:
# n: [  3.  26.  75. 147. 235. 262. 165.  65.  18.   4.]
#  bins: 10

# %% [markdown]
# **Nota**: la función `hist` además nos devuelve dos vectores relevantes. El vector `n` donde nos especifica el número de cuentas de cada bin (columna) del histograma. Y el vector `bins`, que nos dice los límites de estos bines (donde empieza y termina cada columna. Noten que el vector 'bins' tiene un largo igual a `len(n)+1`.
#
# Como último ejemplo, vamos a graficar el histograma de precios correspondientes a los vinos argentinos con una calificación de 85 y los vamos a comparar al precio de los vinos argentinos con una calificación de 90.
